# %%
from candidateClass import Candidate2017

# %%
df = Candidate2017("https://info.kingcounty.gov/kcelections/Vote/contests/candidates.aspx?eid=9")

# %%
df.allCandidates[['district', 'race', 'candidate_name']]
# Out:
#                               district                        race  \
# candidate3451  Legislative District 31               State Senator
# candidate3450  Legislative District 31               State Senator
# candidate3452  Legislative District 31   Representative Position 2
# candidate3453  Legislative District 31   Representative Position 2
# candidate3454  Legislative District 37               State Senator
# candidate3455  Legislative District 45               State Senator
# candidate3456  Legislative District 45               State Senator
# candidate3457  Legislative District 48               State Senator
# candidate3458  Legislative District 48               State Senator
# candidate3459  Legislative District 48   Representative Position 1
# candidate3460  Legislative District 48   Representative Position 1
#
#                      candidate_name
# candidate3451        Phil Fortunato
# candidate3450      Michelle Rylands
# candidate3452          Morgan Irwin
# ...
