# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/allCandidates.pkl')
df[['candidate_name', 'race', 'district']]
# Out:
#                      candidate_name                        race  \
# candidate3451        Phil Fortunato               State Senator
# candidate3450      Michelle Rylands               State Senator
# candidate3452          Morgan Irwin   Representative Position 2
# candidate3453            Nate Lowry   Representative Position 2
# candidate3454       Rebecca Saldaña               State Senator
# candidate3455         Manka Dhingra               State Senator
# candidate3456  Jinyoung Lee Englund               State Senator
# candidate3457         Patty Kuderer               State Senator
# candidate3458      Michelle Darnell               State Senator
# candidate3459       Vandana Slatter   Representative Position 1
# candidate3460      Ciaran Dougherty   Representative Position 1
#
#                               district
# candidate3451  Legislative District 31
# candidate3450  Legislative District 31
# candidate3452  Legislative District 31
# ...
